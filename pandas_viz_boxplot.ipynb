# %%
import pandas as pd
# %matplotlib inline
pd.__version__
# Out:
# '2.0.3'

# %%
df=pd.read_csv('https://github.com/prasertcbs/tutorial/raw/master/mpg.csv')
df.sample(10)
# Out:
#     manufacturer                model  displ  year  cyl       trans drv  cty  \
# 58         dodge          durango 4wd    4.7  2008    8    auto(l5)   4   13
# 228   volkswagen               passat    1.8  1999    4    auto(l5)   f   18
# 153       nissan       pathfinder 4wd    5.6  2008    8    auto(s5)   4   12
# 164       subaru         forester awd    2.5  2008    4    auto(l4)   4   18
# 223   volkswagen           new beetle    2.0  1999    4  manual(m5)   f   21
# 139      mercury      mountaineer 4wd    4.6  2008    8    auto(l6)   4   13
# 67         dodge  ram 1500 pickup 4wd    4.7  2008    8    auto(l5)   4   13
# 161       subaru         forester awd    2.5  2008    4  manual(m5)   4   20
# 3           audi                   a4    2.0  2008    4    auto(av)   f   21
# 96          ford              mustang    4.6  2008    8  manual(m5)   r   15
#
#      hwy fl       class
# 58    17  r         suv
# 228   29  p     midsize
# 153   18  p         suv
# ...

# %%
df.cty.plot.box();

# %%
df.boxplot()
# Out:
# <Axes: >

# %%
df[['cty', 'hwy']].plot.box()
# Out:
# <Axes: >

# %%
df[['cty', 'hwy']].boxplot();

# %%
df.boxplot(column=['cty', 'hwy'])

# %%
df.boxplot(column=['cty', 'hwy'], by='drv')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x10e6f8748>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x10e79e438>], dtype=object)

# %%
df.boxplot(column=['cty', 'hwy'], by='drv', grid=False)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x10e889d68>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x10e948a58>], dtype=object)

# %%
df.boxplot(column='cty', by=['class', 'drv'])

# %%
df.boxplot(column='cty', by=['class', 'drv'], rot=90, grid=False)

# %%
df.boxplot(column='cty', by=['class', 'drv'], vert=False, grid=False);

# %%
df.boxplot(column=['cty', 'hwy'], by=['class', 'drv'], vert=False, grid=False);

# %%
df.boxplot(column=['cty', 'hwy'], by=['class', 'drv'], vert=False, grid=False, figsize=(10, 5));
